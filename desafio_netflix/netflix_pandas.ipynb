# %%
import csv
import json
import os
import collections
import pandas as pd

# ARCHIVOS
ruta =  os.getcwd()
ruta_archivo = os.path.join(ruta,"netflix_titles.csv")
with open(ruta_archivo,encoding="utf-8") as archivo:
    dataset = pd.read_csv(archivo)
    print(dataset.columns)
    filtro = dataset[(dataset["release_year"] >= 2010) & (dataset["type"] == "TV Show")]
    filtro_agrupado = filtro.groupby(["type", "release_year"])["title"].count()
    print(filtro_agrupado)
    filtro_agrupado.plot(kind="bar")
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# type     release_year
# TV Show  2010             40
#          2011             40
#          2012             64
#          2013             63
#          2014             88
#          2015            162
#          2016            244
#          2017            265
#          2018            380
#          2019            397
#          2020            436
#          2021            315
# Name: title, dtype: int64
